# %%
import pandas as pd
from deep_translator import GoogleTranslator
from spellchecker import SpellChecker
import numpy as np

# %% [markdown]
# # Forced-choice

# %%
df_esp = pd.read_csv('../clean_data_mturk_espanol/forced_choice_emotion_mturk_espanol.csv')
df_labels_esp = pd.read_csv('../data_mturk_espanol/emotion_labels_espanol.csv')

# %% [markdown]
# ## Manual translation
#
# **The VADER sentiment analyzer only works in English**. I had two options:
#
# - Using a bilingual sentiment analyzer
# - Translating to English and then use VADER
#
# Since I couldn't find a "widely used" bilingual sentiment analyzer, and translating was straightforward, I opted fot the latter

# %%
def translation_emotions(df):
    df.replace(['Enfado'], 'Anger', inplace=True)
    df.replace(['Felicidad'], 'Happiness', inplace=True)
    df.replace(['Sorpresa'], 'Surprise', inplace=True)
    df.replace(['Tristeza'], 'Sadness', inplace=True)
    df.replace(['Asco'], 'Disgust', inplace=True)
    df.replace(['Incertidumbre'], 'Uncertain', inplace=True)
    df.replace(['Miedo'], 'Fear', inplace=True)
    df.replace(['Otra'], 'Other', inplace=True)
    
    return df

# %%
df = translation_emotions(df_esp).copy(deep=True)
df_labels = df_labels_esp.copy(deep=True)

# %%
df_emo_answers_wide = df.loc[:, 'Q2.1':'Q195.1'] # subset photos

# %% [markdown]
# ## Long format DF

# %%
df_emo_answers_long = df_emo_answers_wide.reset_index()
df_emo_answers_long['index'] = df_emo_answers_long.index
df_emo_answers_long = df_emo_answers_long.rename(columns={'index':'participantId'})
df_emo_answers_long.head(2)
# Out:
#    participantId     Q2.1       Q3.1   Q4.1       Q5.1   Q6.1   Q7.1     Q8.1  \
# 0              0    Other  Uncertain  Anger      Other  Anger  Anger    Other
# 1              1  Neutral      Anger  Anger  Uncertain  Anger  Anger  Neutral
#
#     Q9.1      Q10.1  ...    Q186.1   Q187.1 Q188.1     Q189.1     Q190.1  \
# 0  Anger    Disgust  ...  Surprise  Neutral  Other  Uncertain    Disgust
# 1  Other  Uncertain  ...  Surprise  Neutral  Other  Happiness  Uncertain
#
#     Q191.1     Q192.1 Q193.1     Q194.1   Q195.1
# 0  Neutral      Other  Other  Uncertain  Neutral
# 1  Neutral  Uncertain  Other      Other  Neutral
#
# [2 rows x 195 columns]

# %%
df_labels['photoId'] =  df_labels['photoId'].str.strip()
photoIds = df_labels['photoId'].tolist()

# %%
df_emo_answers_long = pd.melt(df_emo_answers_long, id_vars=['participantId'], value_vars=photoIds).reset_index(drop=True).sort_values(by=['participantId'])

# %%
df_emo_answers_long = df_emo_answers_long.rename(columns={'variable':'photoId', 'value':'emotion'})

# %%
df_emo_answers_long_m = pd.merge(df_emo_answers_long, df_labels, how="left", on=["photoId"], validate="many_to_one")

# %%
df_emo_answers_long_m.head(2)
# Out:
#    participantId photoId  emotion ethnicity     sex    age    label  \
# 0              0    Q2.1    Other     bipoc  female  adult   enfado
# 1              0   Q99.1  Neutral     bipoc  female  adult  neutral
#
#                                                  url
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...

# %% [markdown]
# ## Sentiment score

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()

# %%
df_emo_answers_long_m['sentimentScore'] = df_emo_answers_long_m['emotion'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
df_emo_answers_long_m.head(2)
# Out:
#    participantId photoId  emotion ethnicity     sex    age    label  \
# 0              0    Q2.1    Other     bipoc  female  adult   enfado
# 1              0   Q99.1  Neutral     bipoc  female  adult  neutral
#
#                                                  url  sentimentScore
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...             0.0
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...             0.0

# %% [markdown]
# ## Center predictors

# %%
df_emo_answers_long_m['sexC'] = df_emo_answers_long_m['sex'].replace({'female': -0.5, 'male': 0.5})
df_emo_answers_long_m['ageC'] = df_emo_answers_long_m['age'].replace({'child': -0.5, 'adult': 0.5})
df_emo_answers_long_m['ethnicityC'] = df_emo_answers_long_m['ethnicity'].replace({'bipoc': -0.5, 'white': 0.5})

# %%
df_emo_answers_long_m.head(2)
# Out:
#    participantId photoId  emotion ethnicity     sex    age    label  \
# 0              0    Q2.1    Other     bipoc  female  adult   enfado
# 1              0   Q99.1  Neutral     bipoc  female  adult  neutral
#
#                                                  url  sentimentScore  sexC  \
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...             0.0  -0.5
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...             0.0  -0.5
#
#    ageC  ethnicityC
# 0   0.5        -0.5
# 1   0.5        -0.5

# %%
df_emo_answers_long_m_fil = df_emo_answers_long_m[df_emo_answers_long_m['label'] != 'attention']
df_emo_answers_long_m_fil = df_emo_answers_long_m_fil.reset_index(drop=True)

# %%
df_emo_answers_long_m_fil.to_csv('../clean_data_mturk_espanol/forced_choice_emotion_mturk_long_format_lmer_espanol.csv', index=False)

# %%
df_emo_answers_long_m_fil.head()
# Out:
#    participantId photoId    emotion ethnicity     sex    age      label  \
# 0              0    Q2.1      Other     bipoc  female  adult     enfado
# 1              0   Q99.1    Neutral     bipoc  female  adult    neutral
# 2              0   Q98.1  Happiness     white    male  child  felicidad
# 3              0   Q97.1    Neutral     white    male  adult  felicidad
# 4              0   Q96.1  Happiness     white  female  child  felicidad
#
#                                                  url  sentimentScore  sexC  \
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...          0.0000  -0.5
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...          0.0000  -0.5
# 2  https://uwmadison.co1.qualtrics.com/ControlPan...          0.5574   0.5
# 3  https://uwmadison.co1.qualtrics.com/ControlPan...          0.0000   0.5
# 4  https://uwmadison.co1.qualtrics.com/ControlPan...          0.5574  -0.5
#
#    ageC  ethnicityC
# 0   0.5        -0.5
# 1   0.5        -0.5
# 2  -0.5         0.5
# 3   0.5         0.5
# 4  -0.5         0.5

# %% [markdown]
# # Free-labeling

# %%
df_free_esp = pd.read_csv('../clean_data_mturk_espanol/free_choice_emotion_mturk_espanol.csv')
df_labels_free = pd.read_csv('../data_mturk_espanol/emotion_labels_free_choice_mturk_espanol.csv')

# %%
df_emo_answers_free = df_free_esp.loc[:, 'Q2.1_1':'Q195.1_4'] # get cols with words only

# %% [markdown]
# ## Manual word clean up

# %%
df_emo_answers_free = df_emo_answers_free.transform(lambda x: x.str.strip(), axis = 1)
df_emo_answers_free = df_emo_answers_free.transform(lambda x: x.str.lower(), axis = 1)
df_emo_answers_free = df_emo_answers_free.transform(lambda x: x.replace({'na':'none'}) , axis = 1)
df_emo_answers_free = df_emo_answers_free.fillna('NAN')

# %%
df_emo_answers_free.head(2)
# Out:
#     Q2.1_1 Q2.1_2 Q2.1_3 Q2.1_4   Q3.1_1 Q3.1_2 Q3.1_3 Q3.1_4   Q4.1_1 Q4.1_2  \
# 0  molesta    NAN    NAN    NAN  molesta    NAN    NAN    NAN  molesto    NAN
# 1   enfado    NAN    NAN    NAN   enfado    NAN    NAN    NAN   enfado    NAN
#
#    ... Q193.1_3 Q193.1_4 Q194.1_1 Q194.1_2 Q194.1_3 Q194.1_4 Q195.1_1  \
# 0  ...      NAN      NAN  molesto      NAN      NAN      NAN  molesto
# 1  ...      NAN      NAN      NAN      NAN      NAN      NAN  neutral
#
#   Q195.1_2 Q195.1_3 Q195.1_4
# 0      NAN      NAN      NAN
# 1      NAN      NAN      NAN
#
# [2 rows x 776 columns]

# %% [markdown]
# ## English translation

# %%
df_stack = df_emo_answers_free.stack().reset_index(drop=True) # stack as series
df_stack = df_stack.to_frame(name='emotion') # as DF
emotion_set = list(set(df_stack['emotion'])) # get distinc words

# %%
## dic for translation
emotion_dic = {}
for i in emotion_set:
    emotion_dic[i] = GoogleTranslator(source='spanish', target='english').translate(i)
    print(emotion_dic[i])
# Out:
# craziness
# complicity
# happiness
# hostility
# flirtatious
# nuisance
# doubtful
# Bad smell
# scared
# reviewing
# drunkenness
# confusion
# disgust
# sensuality
# annoying
# nerve
# indifferent
# suffering
# dazzled
# shocked
# provocation
# neutral
# joy
# pissed off
# bleak
# spoiled
# happiness
# discomfort
# disorientated
# fun
# approval
# confidence
# critical
# intimidating
# despair
# aversion
# interested
# weeping
# evaluation
# restless
# betrayed
# caveat
# irony
# bewilderment
# surprise
# horrified
# smelly
# smiling
# copy
# fighting
# inquisitive
# threat
# shock
# man of steel in disgrace
# apathetic
# remembrance
# nice to meet you
# bored
# Attention
# pleasant
# silly
# introspection
# claim
# play
# coldness
# distressed
# bitter
# Superman
# disgust
# sympathetic
# tearful
# desire
# fed up
# disgust
# hysteria
# trance
# fascination
# impressed
# Grace
# I knew
# disappointed
# sentimental
# irony
# falsehood
# simulation
# pensive
# euphoria
# observer
# annoyed
# naive
# inconsolable
# illness
# jocular
# disoriented
# vain
# crying
# surprised
# nostalgia
# sorry
# fascinated
# laughter
# unmotivated
# irritation
# mystery
# harmony
# listless
# concentration
# complacency
# gonna
# insecurity
# ironic
# indignant
# misunderstanding
# concentration
# cooperation
# shocking
# cry
# determination
# Smiley
# depression
# frightened
# bored
# melancholia
# rogue
# euphoric
# embarrassed
# upset
# moved
# playful
# sleep
# questions
# believed
# negativity
# desolation
# shock
# joke
# repentance
# uncomfortable
# delicious
# irritated
# seduction
# effort
# insecure
# jaded
# disorientation
# confrontation
# questioning
# indifference
# tired
# assertiveness
# annoyance
# excited
# condemned
# approval
# threat
# I laughed
# grumpy
# disappointment
# suspicious
# arguing
# inconsiderate
# pleasant
# shyness
# treason
# naughty
# scare
# uncomfortable
# sad
# satisfaction
# I long
# ugly
# sure
# positive
# disapproval
# liking
# annoyed
# suspicion
# funny
# brave
# mania
# discouragement
# sassy Girl
# peaceful
# egocentrism
# hyperactive
# intimidated
# funny
# sarcasm
# scary
# crying
# hilarity
# smile
# comedian
# strangeness
# indignation
# distressed
# observing
# sadness
# abandonment
# rejection
# cautious
# jester
# disgusting
# violent
# resentment
# incredulous
# hurt
# heaviness
# fascinated
# peace
# amazing
# disgust
# examining
# fault
# satisfied
# happy
# smiled
# afraid
# suspicious
# I disapprove
# coquetry
# convicted
# concern
# quiet
# fearful
# bold
# anxiety
# admiration
# angry
# scolding
# Surprised
# restless
# challenging
# sulky
# according
# impotence
# bad gal
# mocking
# Doubts
# repulsion
# startled
# answer
# tantrum
# disappointment
# clown
# rabid
# reflective
# cordiality
# malevolent
# serenity
# attentive
# terrified
# lamented
# captivated
# why
# irritable
# furious
# denial
# tranquility
# horror
# satisfaction
# surprised
# neutrality
# concern
# euphoric
# expectant
# horrified
# drama
# celebrating
# insolent
# disbelief
# surprised
# contempt
# depressed
# joy
# disappointment
# celebration
# candid
# crestfallen
# funny
# hurt
# naive
# security
# impact
# mischief
# heartbroken
# careless
# irritated
# skepticism
# hatred
# resentment
# concern
# distrust
# funny
# thunderstruck
# safe
# Print
# wiseacre
# fear
# psychotic
# stinky
# imitation
# performance
# funny
# irreverence
# afflicted
# hunger
# sassy Girl
# claim
# coquette
# remembering
# scream
# fun
# notch
# surprised
# pedantic
# disenchanted
# intrigued
# sweetie
# apathy
# serene
# panic
# dislike
# enjoyment
# abandonment
# unhappy
# perplexed
# distracted
# innocence
# disappointed
# disrespectful
# fetid
# spoiled
# concentrated
# graceful
# irritation
# observant
# caring
# disgusted
# puzzled
# pleasant
# expectation
# ironic
# delusion
# can
# pain
# panic
# nervous
# blunt
# indecision
# incomprehension
# ecstasy
# amiability
# doubtful
# clarity
# cringe
# repudiation
# trauma
# confusion
# love
# seriousness
# deep
# braggart
# Waiting answer
# sensual
# interest
# calm
# suspicious
# scared
# disagreement
# confusion
# Clark Kent
# sorry
# disagreement
# conceited
# annoyance
# boredom
# I didn't expect it from you
# happiness
# abandoned
# hoping for
# shameless
# annoyed
# analytical
# attentiveness
# disconsolate
# hallucinated
# sweet
# listless
# loneliness
# discomfort
# frightening
# resignation
# distracted
# serene
# surprise
# comfort
# missed
# excitement
# unexpected
# comfortable
# upset
# concentrated
# attention
# repulsion
# laughs
# concern
# pleased
# unpleasant
# terrible
# derision
# annoying
# concentration
# laughing
# thought
# cautious
# rabid
# surprise
# aggressiveness
# delusion
# immaturity
# deconcentration
# surprise
# nan
# believed
# presumptuous
# coquetry
# disenchanted
# fatigue
# challenging
# strain
# stubborn
# alert
# lament
# disappointment
# fervor
# libido
# surprise
# reprobation
# contempt
# appreciation
# direct
# charm
# suffering
# bad move
# overwhelmed
# glad
# rage
# incredulous
# natural
# surprise
# candidate
# malicious
# rude
# doubtful
# exquisite
# Print
# disinterest
# enraged
# genius
# powerful
# upset
# disinterest
# mischievous
# dissatisfied
# reflection
# picardia
# Calm down
# intrigued
# despair
# protester
# optimistic
# bowled over
# guilty
# relax
# stunned
# Thoughtful
# concentrated
# afraid
# ridiculous
# aggressive
# cheerful
# melancholy
# denial
# jovial
# earring
# uneasy
# dissatisfaction
# threatening
# anger
# confused
# emotion
# tired
# unknown
# amazed
# terror
# effusive
# intriguing
# disconsolately
# upset
# bad attitude
# nasty
# distracted
# disparagement
# jokes
# incredulous
# calmed down
# exhibitionism
# scolded
# anger
# cautious
# disappointed
# protest
# mourn
# overwhelmed
# disgusted
# delighted
# expressionless
# courage
# naive
# uncertainty
# inquisitiveness
# hypocrisy
# emotion
# whim
# proud
# admiration
# moody
# undecided
# satiety
# joy
# mischievous
# challenging
# intimidated
# clown
# sincere
# overwhelmed
# shock
# malice
# romp
# funny
# gape
# discomfort
# smug
# confusion
# grin
# relief
# nervousness
# happiness
# to persuade
# embarrassment
# spoiled
# nice
# desolate
# dejected
# shriveled
# Screaming
# smiling
# funny
# poor appetite
# disdain
# sad
# impressed
# grotesque
# chance
# sympathy
# coward
# stupor
# melancholy
# interested
# scared
# playful
# amazed
# sadness
# pride
# confused
# pleased
# embittered
# stress
# submission
# mocking
# frustration
# disappointment
# terrified
# empathy
# choleric
# fearful
# worried
# taste
# resentful
# aware
# decision
# passion
# curiosity
# innocent
# horrible
# frustrated
# would be
# rude
# motivated
# mocking
# Rage
# amazed
# sarcasm
# spontaneous
# joy
# sadness
# optimistic
# disorientation
# discovered
# doubt
# furious
# to weigh
# missed
# stunned
# joker
# frightened
# grumpy
# in love
# interest
# distress
# effusive
# que
# braggart
# shocked
# surprised
# tasty
# asco
# formal
# relaxed
# distant
# shame
# disgust
# happiness
# distraction
# acidity
# clown
# depressed
# concerned
# embarrassment
# reaction
# tranquility
# repellency
# certain
# disgusting
# disappointment
# happy
# sore
# funny
# striving
# naive
# none
# repulsion
# melancholia
# outgoing
# lonely
# astonishment
# scaredy
# afflicted
# admired
# silly faces
# effusiveness
# expression
# notice
# simple
# disbelief
# smelly
# smiled
# sign
# pleasure
# hardness
# obfuscated
# downcast
# interested
# grief
# confused
# glutton
# Bravo
# hope
# disapproval
# persuasion
# surprise
# containment
# irreverent
# intuition
# enraged
# terror
# trustworthy
# introvert
# discouraged
# disappointment
# discontent
# sore
# disgusted
# courage
# expectation
# nonconformity
# mischief
# cheerful
# peaceful
# shocked
# deep
# annoyed
# something sucks
# affliction
# grief
# annoying
# listless
# in agreement
# intrigue
# approval
# fear
# strength
# presumption
# stunned
# fun
# confess
# tearful
# attentive

# %%
df_emo_answers_free_en = df_emo_answers_free.replace(emotion_dic)

# %%
df_labels_free['photoId'] = df_emo_answers_free.columns.tolist()
df_labels_free.tail(2)
# Out:
#     ethnicity   sex    age          label  \
# 774     white  male  child  incertidumbre
# 775     white  male  child  incertidumbre
#
#                                                    url   photoId
# 774  https://uwmadison.co1.qualtrics.com/ControlPan...  Q195.1_3
# 775  https://uwmadison.co1.qualtrics.com/ControlPan...  Q195.1_4

# %% [markdown]
# ## Long-form DF

# %%
df_emo_answers_free_long = df_emo_answers_free_en.reset_index()
df_emo_answers_free_long['index'] = df_emo_answers_free_long.index
df_emo_answers_free_long = df_emo_answers_free_long.rename(columns={'index':'participantId'})
df_emo_answers_free_long.head(2)
# Out:
#    participantId Q2.1_1 Q2.1_2 Q2.1_3 Q2.1_4 Q3.1_1 Q3.1_2 Q3.1_3 Q3.1_4  \
# 0              0  upset    nan    nan    nan  upset    nan    nan    nan
# 1              1  anger    nan    nan    nan  anger    nan    nan    nan
#
#   Q4.1_1  ... Q193.1_3 Q193.1_4 Q194.1_1 Q194.1_2 Q194.1_3 Q194.1_4 Q195.1_1  \
# 0  upset  ...      nan      nan    upset      nan      nan      nan    upset
# 1  anger  ...      nan      nan      nan      nan      nan      nan  neutral
#
#   Q195.1_2 Q195.1_3 Q195.1_4
# 0      nan      nan      nan
# 1      nan      nan      nan
#
# [2 rows x 777 columns]

# %%
# df_labels['photoId'] =  df_labels['photoId'].str.strip()
photoIds = df_labels_free['photoId'].tolist()

# %%
df_emo_answers_free_long = pd.melt(df_emo_answers_free_long, 
                                   id_vars=['participantId'], 
                                   value_vars=photoIds).reset_index(drop=True).sort_values(by=['participantId'])

# %%
df_emo_answers_free_long = df_emo_answers_free_long.rename(columns={'variable':'photoId', 'value':'emotion'})

# %%
## replace with np.nan to drop it 
dic_nan = {'nan': np.nan, 'none': np.nan}

df_emo_answers_free_long['emotion'] = df_emo_answers_free_long['emotion'].replace(dic_nan)

# %%
df_emo_answers_free_long.head()
# Out:
#        participantId   photoId emotion
# 0                  0    Q2.1_1   upset
# 15279              0  Q117.1_4     NaN
# 15312              0  Q118.1_1  afraid
# 15345              0  Q118.1_2   upset
# 15378              0  Q118.1_3     NaN

# %% [markdown]
# ## Check and drop NA

# %%
df_emo_answers_free_long.isna().sum(), df_emo_answers_free_long.shape
# Out:
# (participantId        0
#  photoId              0
#  emotion          16159
#  dtype: int64,
#  (25608, 3))

# %%
## drop np.nan
df_emo_answers_free_long_drop = df_emo_answers_free_long.dropna()

df_emo_answers_free_long_drop.isna().sum(), df_emo_answers_free_long_drop.shape
# Out:
# (participantId    0
#  photoId          0
#  emotion          0
#  dtype: int64,
#  (9449, 3))

# %%
df_emo_answers_free_long_m = pd.merge(df_emo_answers_free_long_drop, df_labels_free, how="left", on=["photoId"], validate="many_to_one")

# %%
df_emo_answers_free_long_m.head(2)
# Out:
#    participantId   photoId emotion ethnicity     sex    age     label  \
# 0              0    Q2.1_1   upset     bipoc  female  adult    enfado
# 1              0  Q118.1_1  afraid     bipoc    male  child  sorpresa
#
#                                                  url
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...

# %%
df_emo_answers_free_long_m.isna().sum(), df_emo_answers_free_long_m.shape
# Out:
# (participantId      0
#  photoId            0
#  emotion            0
#  ethnicity        112
#  sex              112
#  age              112
#  label              0
#  url                0
#  dtype: int64,
#  (9449, 8))

# %% [markdown]
# ## Manual english correction and removing sentences

# %%
## we want to get rid of sentences and leave single words

## count length sentences 
df_emo_answers_free_long_m['len_words'] = df_emo_answers_free_long_m['emotion'].str.split().apply(len)

## get list of distinct sentences (>= 2 words)
list_sentences = df_emo_answers_free_long_m[df_emo_answers_free_long_m['len_words'] >= 2].value_counts('emotion').index.tolist()

list_sentences
# Out:
# ['Calm down',
#  'I laughed',
#  'would be',
#  'to weigh',
#  'sassy Girl',
#  'I long',
#  'calmed down',
#  'hoping for',
#  'I disapprove',
#  'pissed off',
#  'nice to meet you',
#  'silly faces',
#  'poor appetite',
#  'in love',
#  'something sucks',
#  'to persuade',
#  'man of steel in disgrace',
#  'Bad smell',
#  'in agreement',
#  'bowled over',
#  'bad move',
#  'bad gal',
#  'bad attitude',
#  'Waiting answer',
#  'I knew',
#  "I didn't expect it from you",
#  'Clark Kent',
#  'fed up']

# %%
## dic for word replacement

dic_sentences = {}

for i in list_sentences:
    dic_sentences[i] = None
    
dic_sentences
# Out:
# {'Calm down': None,
#  'I laughed': None,
#  'would be': None,
#  'to weigh': None,
#  'sassy Girl': None,
#  'I long': None,
#  'calmed down': None,
#  'hoping for': None,
#  'I disapprove': None,
#  'pissed off': None,
#  'nice to meet you': None,
#  'silly faces': None,
#  'poor appetite': None,
#  'in love': None,
#  'something sucks': None,
#  'to persuade': None,
#  'man of steel in disgrace': None,
#  'Bad smell': None,
#  'in agreement': None,
#  'bowled over': None,
#  'bad move': None,
#  'bad gal': None,
#  'bad attitude': None,
#  'Waiting answer': None,
#  'I knew': None,
#  "I didn't expect it from you": None,
#  'Clark Kent': None,
#  'fed up': None}

# %%
## there is no choice but manual translation/fixing for these ones

dic_sentences['go to'] = 'wrath' ## Google Translate is spliting 'ira' (wrath) into 'ir a'
dic_sentences['in tears'] =  'crying'
dic_sentences['Calm down'] =  'calm'
dic_sentences['calmed down'] =  'calm'
dic_sentences['I laughed'] =  'laughing'
dic_sentences['would be'] =  'serious' ## 'serio = serious' 'seria = would be' 
dic_sentences['sassy Girl'] =  'sassy'
dic_sentences['I long'] = 'longing'
dic_sentences['I disapprove'] = 'disapprove'
dic_sentences['something sucks'] = 'sucks'
dic_sentences['silly faces'] = 'silly'
dic_sentences['poor appetite'] = ''
dic_sentences['nice to meet you'] = 'nice'
dic_sentences['in love'] = 'love'
dic_sentences['Bad smell'] = 'smelly'
dic_sentences['fed up'] = 'disgusted'
dic_sentences['bad gal'] = 'bad'
dic_sentences['Waiting answer'] = 'expectant'
dic_sentences['bowled over'] = 'surprised'
dic_sentences['Clark Kent'] = np.nan
dic_sentences['He shouted'] = 'shouting'
dic_sentences['I knew'] = 'know'
dic_sentences['bad attitude'] = 'gloomy'
dic_sentences['bad move'] = np.nan
dic_sentences['in love'] = 'love'
dic_sentences['man of steel in disgrace'] = 'disgraced'
dic_sentences['poor appetite'] = 'satiated'
dic_sentences["I didn't expect it from you"] = np.nan

# %%
## to search for 'keys' based on 'value'
print(list(emotion_dic.keys())[list(emotion_dic.values()).index('bad move')])
# Out:
# mala jugada

# %%
dic_sentences
# Out:
# {'Calm down': 'calm',
#  'I laughed': 'laughing',
#  'would be': 'serious',
#  'to weigh': None,
#  'sassy Girl': 'sassy',
#  'I long': 'longing',
#  'calmed down': 'calm',
#  'hoping for': None,
#  'I disapprove': 'disapprove',
#  'pissed off': None,
#  'nice to meet you': 'nice',
#  'silly faces': 'silly',
#  'poor appetite': 'satiated',
#  'in love': 'love',
#  'something sucks': 'sucks',
#  'to persuade': None,
#  'man of steel in disgrace': 'disgraced',
#  'Bad smell': 'smelly',
#  'in agreement': None,
#  'bowled over': 'surprised',
#  'bad move': nan,
#  'bad gal': 'bad',
#  'bad attitude': 'gloomy',
#  'Waiting answer': 'expectant',
#  'I knew': 'know',
#  "I didn't expect it from you": nan,
#  'Clark Kent': nan,
#  'fed up': 'disgusted',
#  'go to': 'wrath',
#  'in tears': 'crying',
#  'He shouted': 'shouting'}

# %%
## replace with new translation

df_emo_answers_free_long_m = df_emo_answers_free_long_m.replace(dic_sentences)

# %%
df_emo_answers_free_long_m
# Out:
#       participantId   photoId    emotion ethnicity     sex    age  \
# 0                 0    Q2.1_1      upset     bipoc  female  adult
# 1                 0  Q118.1_1     afraid     bipoc    male  child
# 2                 0  Q118.1_2      upset     bipoc    male  child
# 3                 0  Q119.1_1  surprised     white  female  adult
# 4                 0  Q120.1_1    neutral     white  female  child
# ...             ...       ...        ...       ...     ...    ...
# 9444             32  Q127.1_1   surprise     white  female  adult
# 9445             32  Q126.1_3   peaceful     bipoc    male  child
# 9446             32  Q126.1_2       calm     bipoc    male  child
# 9447             32  Q126.1_1       calm     bipoc    male  child
# 9448             32  Q128.1_2      grief     white  female  child
#
#               label                                                url  \
# 0            enfado  https://uwmadison.co1.qualtrics.com/ControlPan...
# 1          sorpresa  https://uwmadison.co1.qualtrics.com/ControlPan...
# 2          sorpresa  https://uwmadison.co1.qualtrics.com/ControlPan...
# 3          sorpresa  https://uwmadison.co1.qualtrics.com/ControlPan...
# 4          sorpresa  https://uwmadison.co1.qualtrics.com/ControlPan...
# ...             ...                                                ...
# 9444  incertidumbre  https://uwmadison.co1.qualtrics.com/ControlPan...
# 9445  incertidumbre  https://uwmadison.co1.qualtrics.com/ControlPan...
# 9446  incertidumbre  https://uwmadison.co1.qualtrics.com/ControlPan...
# 9447  incertidumbre  https://uwmadison.co1.qualtrics.com/ControlPan...
# 9448  incertidumbre  https://uwmadison.co1.qualtrics.com/ControlPan...
#
#       len_words
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 9444          1
# 9445          1
# 9446          1
# 9447          2
# 9448          1
#
# [9449 rows x 9 columns]

# %%
# clean up text from:
# 1. phrases
# 2. words with numbers 
# 3. words with non alphabetic symbols
# 4. words shorter than three characters
# 5. words that appear just once

# %%
df_emo_answers_free_long_m = df_emo_answers_free_long_m.dropna()
df_emo_answers_free_long_m['emotion_txt'] = df_emo_answers_free_long_m['emotion'].str.lower() # as lower case
df_emo_answers_free_long_m['emotion_txt'] = df_emo_answers_free_long_m['emotion_txt'].replace({'na':'none'}) 
df_emo_answers_free_long_m['emotion_txt'] = df_emo_answers_free_long_m['emotion_txt'].astype(str) # as str
df_emo_answers_free_long_m['len_words'] = df_emo_answers_free_long_m['emotion_txt'].str.split().apply(len) # count words per answer
df_emo_answers_free_long_m = df_emo_answers_free_long_m[df_emo_answers_free_long_m['len_words'] <= 1] # keep single word answers
df_emo_answers_free_long_m['len_letters'] = df_emo_answers_free_long_m['emotion_txt'].apply(len) # cont number of letters
df_emo_answers_free_long_m = df_emo_answers_free_long_m[df_emo_answers_free_long_m['len_letters'] >= 3] # keep words with 3 or more letters
df_emo_answers_free_long_m['emotion_txt'] = df_emo_answers_free_long_m['emotion_txt'].str.replace('[^a-zA-Z]', '') # remove non-alphabetic characters
df_emo_answers_free_long_m = df_emo_answers_free_long_m[~df_emo_answers_free_long_m['emotion_txt'].str.contains(r'[0-9]')] #drop words containing numbers
df_emo_answers_free_long_m = df_emo_answers_free_long_m[df_emo_answers_free_long_m.groupby('emotion_txt').emotion_txt.transform(len) > 1] # keep words that ocurr > 1
# Out:
# /home/pablo_ubuntu/miniconda3/envs/venv/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# /tmp/ipykernel_344/4085132066.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_emo_answers_free_long_m['emotion_txt'] = df_emo_answers_free_long_m['emotion_txt'].str.replace('[^a-zA-Z]', '') # remove non-alphabetic characters

# %%
## recheck NAN values
df_emo_answers_free_long_m.isna().sum(), df_emo_answers_free_long_m.shape
# Out:
# (participantId    0
#  photoId          0
#  emotion          0
#  ethnicity        0
#  sex              0
#  age              0
#  label            0
#  url              0
#  len_words        0
#  emotion_txt      0
#  len_letters      0
#  dtype: int64,
#  (9130, 11))

# %%
## drop np.nan
df_emo_answers_free_long_m = df_emo_answers_free_long_m.dropna()

df_emo_answers_free_long_m.isna().sum(), df_emo_answers_free_long_m.shape
# Out:
# (participantId    0
#  photoId          0
#  emotion          0
#  ethnicity        0
#  sex              0
#  age              0
#  label            0
#  url              0
#  len_words        0
#  emotion_txt      0
#  len_letters      0
#  dtype: int64,
#  (9130, 11))

# %%
#### recheck sentences

## count length sentences 
df_emo_answers_free_long_m['len_words'] = df_emo_answers_free_long_m['emotion'].str.split().apply(len)

## get list of distinct sentences (>= 2 words)
list_sentences_ = df_emo_answers_free_long_m[df_emo_answers_free_long_m['len_words'] >= 2].value_counts('emotion').index.tolist()

list_sentences_
# Out:
# []

# %%
## remove unnecesary column

df_emo_answers_free_long_m.drop(['len_words', 'len_letters', 'emotion'], axis=1, inplace=True)
df_emo_answers_free_long_m.rename(columns={"emotion_txt": "emotion"}, inplace=True)
df_emo_answers_free_long_m.head()
# Out:
#    participantId   photoId ethnicity     sex    age     label  \
# 0              0    Q2.1_1     bipoc  female  adult    enfado
# 1              0  Q118.1_1     bipoc    male  child  sorpresa
# 2              0  Q118.1_2     bipoc    male  child  sorpresa
# 3              0  Q119.1_1     white  female  adult  sorpresa
# 4              0  Q120.1_1     white  female  child  sorpresa
#
#                                                  url    emotion
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...      upset
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...     afraid
# 2  https://uwmadison.co1.qualtrics.com/ControlPan...      upset
# 3  https://uwmadison.co1.qualtrics.com/ControlPan...  surprised
# 4  https://uwmadison.co1.qualtrics.com/ControlPan...    neutral

# %% [markdown]
# ## Sentiment score

# %%
## compute sentiment score for each word
df_emo_answers_free_long_m['sentimentScore'] = df_emo_answers_free_long_m['emotion'].apply(lambda x: sia.polarity_scores(x)['compound'])

# %%
df_emo_answers_free_long_m.head(2)
# Out:
#    participantId   photoId ethnicity     sex    age     label  \
# 0              0    Q2.1_1     bipoc  female  adult    enfado
# 1              0  Q118.1_1     bipoc    male  child  sorpresa
#
#                                                  url emotion  sentimentScore
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...   upset         -0.3818
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...  afraid          0.0000

# %% [markdown]
# ## Center predictors

# %%
df_emo_answers_free_long_m['sexC'] = df_emo_answers_free_long_m['sex'].replace({'female': -0.5, 'male': 0.5})
df_emo_answers_free_long_m['ageC'] = df_emo_answers_free_long_m['age'].replace({'child': -0.5, 'adult': 0.5})
df_emo_answers_free_long_m['ethnicityC'] = df_emo_answers_free_long_m['ethnicity'].replace({'bipoc': -0.5, 'white': 0.5})

# %%
df_emo_answers_free_long_m.head(2)
# Out:
#    participantId   photoId ethnicity     sex    age     label  \
# 0              0    Q2.1_1     bipoc  female  adult    enfado
# 1              0  Q118.1_1     bipoc    male  child  sorpresa
#
#                                                  url emotion  sentimentScore  \
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...   upset         -0.3818
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...  afraid          0.0000
#
#    sexC  ageC  ethnicityC
# 0  -0.5   0.5        -0.5
# 1   0.5  -0.5        -0.5

# %%
df_emo_answers_free_long_m_fil = df_emo_answers_free_long_m[df_emo_answers_free_long_m['label'] != 'attention']
df_emo_answers_free_long_m_fil = df_emo_answers_free_long_m_fil.reset_index(drop=True)

# %%
df_emo_answers_free_long_m_fil.head(2)
# Out:
#    participantId   photoId ethnicity     sex    age     label  \
# 0              0    Q2.1_1     bipoc  female  adult    enfado
# 1              0  Q118.1_1     bipoc    male  child  sorpresa
#
#                                                  url emotion  sentimentScore  \
# 0  https://uwmadison.co1.qualtrics.com/ControlPan...   upset         -0.3818
# 1  https://uwmadison.co1.qualtrics.com/ControlPan...  afraid          0.0000
#
#    sexC  ageC  ethnicityC
# 0  -0.5   0.5        -0.5
# 1   0.5  -0.5        -0.5

# %%
df_emo_answers_free_long_m_fil.to_csv('../clean_data_mturk_espanol/free_labeling_emotion_mturk_long_format_lmer_espanol.csv', index=False)
